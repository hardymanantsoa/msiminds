# %%
# Machine Learning - Morpion Adaptatif

## Importations et chargement des données

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('ressources/dataset.csv')
print("Forme du dataset :", df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 15
#      13 from sklearn.ensemble import RandomForestClassifier
#      14 from sklearn.neural_network import MLPClassifier
# ---> 15 from xgboost import XGBClassifier
#      16 import warnings
#      17 warnings.filterwarnings('ignore')
#
# ModuleNotFoundError: No module named 'xgboost'

# %% [markdown]
#  # EDA (Exploratory Data Analysis)

# %%
# Distribution des cibles
fig, axes = plt.subplots(1,2, figsize=(10,4))
df['x_wins'].value_counts().plot(kind='bar', ax=axes[0], title='x_wins')
df['is_draw'].value_counts().plot(kind='bar', ax=axes[1], title='is_draw')
plt.tight_layout()
plt.show()

# Déséquilibre ?
print("Proportion x_wins = 1 :", df['x_wins'].mean())
print("Proportion is_draw = 1 :", df['is_draw'].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Distribution des cibles
#       2 fig, axes = plt.subplots(1,2, figsize=(10,4))
# ----> 3 df['x_wins'].value_counts().plot(kind='bar', ax=axes[0], title='x_wins')
#       4 df['is_draw'].value_counts().plot(kind='bar', ax=axes[1], title='is_draw')
#       5 plt.tight_layout()
#
# NameError: name 'df' is not defined
